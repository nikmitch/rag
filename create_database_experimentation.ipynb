# %% [markdown]
# Had some serious issues with this badboy - had to upgrade python to 3.12 (I prob should never have been using 3.8) to get rid of a TypeError about bases and also downgrade the version of chromadb to  0.4.14 to avoid a error about trying to write to a read-only database (see [link](https://github.com/langchain-ai/langchain/issues/14872))

# %%
# from langchain.document_loaders import DirectoryLoader
from langchain_community.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
# from langchain.embeddings import OpenAIEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
import openai 
from dotenv import load_dotenv
import os
import shutil

# Load environment variables. Assumes that project contains .env file with API keys
load_dotenv()
#---- Set OpenAI API key 
# Change environment variable name from "OPENAI_API_KEY" to the name given in 
# your .env file.
openai.api_key = os.environ['OPENAI_API_KEY']

CHROMA_PATH = "chroma"
# DATA_PATH = "data/books"
DATA_PATH = "data/wizard_of_oz"

# %% [markdown]
# # previous code - functionised. I want to step through this more line-by-line

# %%
#previous code - functionised. I want to step through this more line-by-line

# def main():
#     generate_data_store()


# # def generate_data_store():
# #     documents = load_documents()
# #     chunks = split_text(documents)
# #     save_to_chroma(chunks)




# def load_documents():
#     loader = DirectoryLoader(DATA_PATH, glob="*.md")
#     documents = loader.load()
#     return documents


# def split_text(documents: list[Document]):
#     text_splitter = RecursiveCharacterTextSplitter(
#         chunk_size=300,
#         chunk_overlap=100,
#         length_function=len,
#         add_start_index=True,
#     )
#     chunks = text_splitter.split_documents(documents)
#     print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

#     document = chunks[10]
#     print(document.page_content)
#     print(document.metadata)

#     return chunks


# def save_to_chroma(chunks: list[Document]):
#     # Clear out the database first.
#     if os.path.exists(CHROMA_PATH):
#         shutil.rmtree(CHROMA_PATH)

#     # Create a new DB from the documents.
#     db = Chroma.from_documents(
#         chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
#     )
#     db.persist()
#     print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}.")


# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## Loading documents in

# %%
# def generate_data_store():
#     documents = load_documents()
#     chunks = split_text(documents)
#     save_to_chroma(chunks)


# def load_documents():
#     loader = DirectoryLoader(DATA_PATH, glob="*.md")
#     documents = loader.load()
#     return documents


# def load_documents():
loader = DirectoryLoader(DATA_PATH, glob="*.md")
documents = loader.load()
    # return documents

# %% [markdown]
# ## Splitting the documents into chunks

# %%
# def split_text(documents: list[Document]):
#     text_splitter = RecursiveCharacterTextSplitter(
#         chunk_size=300,
#         chunk_overlap=100,
#         length_function=len,
#         add_start_index=True,
#     )
#     chunks = text_splitter.split_documents(documents)
#     print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

#     document = chunks[10]
#     print(document.page_content)
#     print(document.metadata)

#     return chunks


# def split_text(documents: list[Document]):
text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )

chunks = text_splitter.split_documents(documents)

# %%
chunks
# Out:
# [Document(metadata={'source': 'data/wizard_of_oz/wizard_of_oz.md', 'start_index': 0}, page_content='\ufeffThe Project Gutenberg eBook of The Wonderful Wizard of Oz'),
#  Document(metadata={'source': 'data/wizard_of_oz/wizard_of_oz.md', 'start_index': 60}, page_content='This ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online'),
#  Document(metadata={'source': 'data/wizard_of_oz/wizard_of_oz.md', 'start_index': 274}, page_content='of the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.'),
# ...

# %%
print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

document = chunks[70]
print(document.page_content)
print(document.metadata)

# print(chunks)
# Out:
# Split 1 documents into 1127 chunks.
# “Who are the Munchkins?” inquired Dorothy.
#
# “They are the people who live in this land of the East where the Wicked
# Witch ruled.”
#
# “Are you a Munchkin?” asked Dorothy.
# {'source': 'data/wizard_of_oz/wizard_of_oz.md', 'start_index': 13261}

# %% [markdown]
# ## Saving to a database

# %%
# def save_to_chroma(chunks: list[Document]):
#     # Clear out the database first.
#     if os.path.exists(CHROMA_PATH):
#         shutil.rmtree(CHROMA_PATH)

#     # Create a new DB from the documents.
#     db = Chroma.from_documents(
#         chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
#     )
#     db.persist()
#     print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}.")


# def save_to_chroma(chunks: list[Document]):
# Clear out the database first.
if os.path.exists(CHROMA_PATH):
    shutil.rmtree(CHROMA_PATH)

# %%
CHROMA_PATH = "chroma"
if os.path.exists(CHROMA_PATH):
    print(CHROMA_PATH)
db = Chroma.from_documents(
    chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
)
# os.mkdir(CHROMA_PATH)

# %%
# Create a new DB from the documents.
db = Chroma.from_documents(
    chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
)

# %%
db.persist()
print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}.")
# Out:
# Saved 1127 chunks to chroma.
# /Users/nikmitchell/miniconda3/envs/rag/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(

# %% [markdown]
# ### Now asking questions - got this function from query_data.py

# %%
db.similarity_search_with_relevance_scores("scarecrow needs", k=3)
# Out:
# [(Document(metadata={'source': 'data/wizard_of_oz/wizard_of_oz.md', 'start_index': 96943}, page_content='Scarecrow; for when he found himself alone in his room he stood\nstupidly in one spot, just within the doorway, to wait till morning. It\nwould not rest him to lie down, and he could not close his eyes; so he\nremained all night staring at a little spider which was weaving its web'),
#   0.8056612608379042),
#  (Document(metadata={'source': 'data/wizard_of_oz/wizard_of_oz.md', 'start_index': 96943}, page_content='Scarecrow; for when he found himself alone in his room he stood\nstupidly in one spot, just within the doorway, to wait till morning. It\nwould not rest him to lie down, and he could not close his eyes; so he\nremained all night staring at a little spider which was weaving its web'),
#   0.8056612608379042),
# ...
